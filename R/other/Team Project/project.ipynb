# %%
df <- data.frame(read.csv("C:/Users/eddie/OneDrive/文档/GitHub/coding-stuff-I-make-from-learning/R/other/Team Project/DiamondsPrices.csv"))
View(df)
# Out:
#       carat cut       color clarity depth table price x    y    z
# 1     0.23  Ideal     E     SI2     61.5  55    326   3.95 3.98 2.43
# 2     0.21  Premium   E     SI1     59.8  61    326   3.89 3.84 2.31
# 3     0.23  Good      E     VS1     56.9  65    327   4.05 4.07 2.31
# 4     0.29  Premium   I     VS2     62.4  58    334   4.20 4.23 2.63
# 5     0.31  Good      J     SI2     63.3  58    335   4.34 4.35 2.75
# 6     0.24  Very Good J     VVS2    62.8  57    336   3.94 3.96 2.48
# 7     0.24  Very Good I     VVS1    62.3  57    336   3.95 3.98 2.47
# 8     0.26  Very Good H     SI1     61.9  55    337   4.07 4.11 2.53
# 9     0.22  Fair      E     VS2     65.1  61    337   3.87 3.78 2.49
# 10    0.23  Very Good H     VS1     59.4  61    338   4.00 4.05 2.39
# 11    0.30  Good      J     SI1     64.0  55    339   4.25 4.28 2.73
# 12    0.23  Ideal     J     VS1     62.8  56    340   3.93 3.90 2.46
# 13    0.22  Premium   F     SI1     60.4  61    342   3.88 3.84 2.33
# 14    0.31  Ideal     J     SI2     62.2  54    344   4.35 4.37 2.71
# 15    0.20  Premium   E     SI2     60.2  62    345   3.79 3.75 2.27
# 16    0.32  Premium   E     I1      60.9  58    345   4.38 4.42 2.68
# 17    0.30  Ideal     I     SI2     62.0  54    348   4.31 4.34 2.68
# 18    0.30  Good      J     SI1     63.4  54    351   4.23 4.29 2.70
# 19    0.30  Good      J     SI1     63.8  56    351   4.23 4.26 2.71
# 20    0.30  Very Good J     SI1     62.7  59    351   4.21 4.27 2.66
# 21    0.30  Good      I     SI2     63.3  56    351   4.26 4.30 2.71
# 22    0.23  Very Good E     VS2     63.8  55    352   3.85 3.92 2.48
# 23    0.23  Very Good H     VS1     61.0  57    353   3.94 3.96 2.41
# 24    0.31  Very Good J     SI1     59.4  62    353   4.39 4.43 2.62
# 25    0.31  Very Good J     SI1     58.1  62    353   4.44 4.47 2.59
# 26    0.23  Very Good G     VVS2    60.4  58    354   3.97 4.01 2.41
# 27    0.24  Premium   I     VS1     62.5  57    355   3.97 3.94 2.47
# 28    0.30  Very Good J     VS2     62.2  57    357   4.28 4.30 2.67
# 29    0.23  Very Good D     VS2     60.5  61    357   3.96 3.97 2.40
# 30    0.23  Very Good F     VS1     60.9  57    357   3.96 3.99 2.42
# ⋮     ⋮     ⋮         ⋮     ⋮       ⋮     ⋮     ⋮     ⋮    ⋮    ⋮
# 53911 0.70  Premium   E     SI1     60.5  58    2753  5.74 5.77 3.48
# 53912 0.57  Premium   E     IF      59.8  60    2753  5.43 5.38 3.23
# 53913 0.61  Premium   F     VVS1    61.8  59    2753  5.48 5.40 3.36
# 53914 0.80  Good      G     VS2     64.2  58    2753  5.84 5.81 3.74
# 53915 0.84  Good      I     VS1     63.7  59    2753  5.94 5.90 3.77
# 53916 0.77  Ideal     E     SI2     62.1  56    2753  5.84 5.86 3.63
# 53917 0.74  Good      D     SI1     63.1  59    2753  5.71 5.74 3.61
# 53918 0.90  Very Good J     SI1     63.2  60    2753  6.12 6.09 3.86
# 53919 0.76  Premium   I     VS1     59.3  62    2753  5.93 5.85 3.49
# 53920 0.76  Ideal     I     VVS1    62.2  55    2753  5.89 5.87 3.66
# 53921 0.70  Very Good E     VS2     62.4  60    2755  5.57 5.61 3.49
# 53922 0.70  Very Good E     VS2     62.8  60    2755  5.59 5.65 3.53
# 53923 0.70  Very Good D     VS1     63.1  59    2755  5.67 5.58 3.55
# 53924 0.73  Ideal     I     VS2     61.3  56    2756  5.80 5.84 3.57
# 53925 0.73  Ideal     I     VS2     61.6  55    2756  5.82 5.84 3.59
# 53926 0.79  Ideal     I     SI1     61.6  56    2756  5.95 5.97 3.67
# 53927 0.71  Ideal     E     SI1     61.9  56    2756  5.71 5.73 3.54
# 53928 0.79  Good      F     SI1     58.1  59    2756  6.06 6.13 3.54
# 53929 0.79  Premium   E     SI2     61.4  58    2756  6.03 5.96 3.68
# 53930 0.71  Ideal     G     VS1     61.4  56    2756  5.76 5.73 3.53
# 53931 0.71  Premium   E     SI1     60.5  55    2756  5.79 5.74 3.49
# 53932 0.71  Premium   F     SI1     59.8  62    2756  5.74 5.73 3.43
# 53933 0.70  Very Good E     VS2     60.5  59    2757  5.71 5.76 3.47
# 53934 0.70  Very Good E     VS2     61.2  59    2757  5.69 5.72 3.49
# 53935 0.72  Premium   D     SI1     62.7  59    2757  5.69 5.73 3.58
# 53936 0.72  Ideal     D     SI1     60.8  57    2757  5.75 5.76 3.50
# 53937 0.72  Good      D     SI1     63.1  55    2757  5.69 5.75 3.61
# 53938 0.70  Very Good D     SI1     62.8  60    2757  5.66 5.68 3.56
# 53939 0.86  Premium   H     SI2     61.0  58    2757  6.15 6.12 3.74
# 53940 0.75  Ideal     D     SI2     62.2  55    2757  5.83 5.87 3.64

# %%
summary(df)
# Out:
#      carat            cut               color             clarity
#  Min.   :0.2000   Length:53940       Length:53940       Length:53940
#  1st Qu.:0.4000   Class :character   Class :character   Class :character
#  Median :0.7000   Mode  :character   Mode  :character   Mode  :character
#  Mean   :0.7979
#  3rd Qu.:1.0400
#  Max.   :5.0100
#      depth           table           price             x
#  Min.   :43.00   Min.   :43.00   Min.   :  326   Min.   : 0.000
#  1st Qu.:61.00   1st Qu.:56.00   1st Qu.:  950   1st Qu.: 4.710
#  Median :61.80   Median :57.00   Median : 2401   Median : 5.700
#  Mean   :61.75   Mean   :57.46   Mean   : 3933   Mean   : 5.731
#  3rd Qu.:62.50   3rd Qu.:59.00   3rd Qu.: 5324   3rd Qu.: 6.540
#  Max.   :79.00   Max.   :95.00   Max.   :18823   Max.   :10.740
#        y                z
#  Min.   : 0.000   Min.   : 0.000
#  1st Qu.: 4.720   1st Qu.: 2.910
#  Median : 5.710   Median : 3.530
#  Mean   : 5.735   Mean   : 3.539
#  3rd Qu.: 6.540   3rd Qu.: 4.040
#  Max.   :58.900   Max.   :31.800

# %% [markdown]
# ## 1. Carat

# %%
par(mfrow=c(1,2))
hist(df$carat, main = "Carat Distribution", xlab = "Carat")
boxplot(df$carat, main = "Carat Distribution", ylab = "Carat")
# Out:
# Plot with title "Carat Distribution"

# %%
barplot(table(df$cut), main = "Cut Distribution", xlab = "Cut", ylab = "Frequency")
# Out:
# Plot with title "Cut Distribution"

# %% [markdown]
# ## 2. Cut

# %%
barplot(table(df$cut), main = "Cut Distribution", xlab = "Cut", ylab = "Frequency")
# Out:
# Plot with title "Cut Distribution"

# %% [markdown]
# ## 3. Color

# %%
barplot(table(df$color), main = "Color Distribution", xlab = "Color", ylab = "Frequency")
# Out:
# Plot with title "Color Distribution"

# %% [markdown]
# ## 4. Clarity

# %%
barplot(table(df$clarity), main = "Clarity Distribution", xlab = "Clarity", ylab = "Frequency")
# Out:
# Plot with title "Clarity Distribution"

# %% [markdown]
# ## 5. Depth

# %%
par(mfrow=c(1,2))
hist(df$depth, main = "Depth Distribution", xlab = "Depth")
plot(df$depth, df$price, main = "Price vs. Depth", xlab = "Depth", ylab = "Price")
# Out:
# Plot with title "Price vs. Depth"

# %% [markdown]
# ## 6. Table

# %%
par(mfrow=c(1,2))
hist(df$table, main = "Table Distribution", xlab = "Table")
plot(df$table, df$price, main = "Price vs. Table", xlab = "Table", ylab = "Price")
# Out:
# Plot with title "Price vs. Table"

# %% [markdown]
# ## 7. Price

# %%
hist(df$price, main = "Price Distribution", xlab = "Price")
boxplot(df$price, main = "Price Distribution", ylab = "Price")
# Out:
# Plot with title "Price Distribution"
# Plot with title "Price Distribution"

# %% [markdown]
# ## 8. x, y, z

# %%
plot(df$x, df$y, main = "Correlation between x and y", xlab = "x", ylab = "y")
plot(df$x, df$z, main = "Correlation between x and z", xlab = "x", ylab = "z")
plot(df$y, df$z, main = "Correlation between y and z", xlab = "y", ylab = "z")
# Out:
# Plot with title "Correlation between x and y"
# Plot with title "Correlation between x and z"
# Plot with title "Correlation between y and z"

# %% [markdown]
# ## Clarity vs Price

# %%
boxplot(price ~ clarity, data = df, main = "Price by Clarity", xlab = "Clarity", ylab = "Price")
# Out:
# Plot with title "Price by Clarity"

# %%
# 將 clarity 轉換為數字
df$clarity_num <- as.numeric(factor(df$clarity, levels = c("I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF")))

# 繪製散佈圖
plot(price ~ carat, data = df, main = "Price by Carat and Clarity", xlab = "Carat", ylab = "Price", col = df$clarity_num)

# 添加圖例
legend("topright", legend = levels(factor(df$clarity, levels = c("I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF"))), col = 1:length(levels(factor(df$clarity, levels = c("I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF")))), pch = 1)
# Out:
# Plot with title "Price by Carat and Clarity"

# %%
library(ggplot2)

# %%
# 繪製散佈圖
ggplot(df, aes(x = carat, y = price, col = clarity_num)) + 
  geom_point() +
  facet_wrap(~ clarity, scales = "free") +
  labs(title = "Price by Carat and Clarity", x = "Carat", y = "Price", color = "Clarity")
# Out:
# plot without title

# %%
# 繪製 scatter plot
ggplot(df, aes(x = carat, y = price, color = clarity)) + 
  geom_point(alpha = 0.2) +
  facet_wrap(~ clarity, ncol = 3) +
  # 繪製回歸線
  stat_smooth(method = "lm", formula = y ~ x, se = FALSE, color = "red") +
  labs(title = "Price vs. Carat for Different Clarity Grades", 
       x = "Carat", y = "Price") +
  scale_color_brewer(palette = "Dark2")
# Out:
# plot without title

# %%
ggplot(df, aes(x = carat, y = price)) +
  geom_point() +
  geom_smooth(aes(color = cut), method = "lm", se = FALSE) +
  facet_wrap(~ cut, ncol = 2)
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %%
ggplot(df, aes(x = carat, y = price)) +
  geom_point() +
  geom_smooth(aes(color = color), method = "lm", se = FALSE) +
  facet_wrap(~ color, ncol = 2)
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %% [markdown]
# ## 看各族群是否符合常態分佈

# %%
library(dplyr)

# %%
table(df$clarity)
# Out:
#    I1    IF   SI1   SI2   VS1   VS2  VVS1  VVS2
#   741  1790 13065  9194  8171 12258  3655  5066

# %% [markdown]
# #### 大於 5000 數值抽樣 5000 個

# %%
df %>%
  group_by(clarity) %>%
  summarize(n = n()) %>%
  mutate(sample_size = if_else(n > 5000, 5000, n)) %>%
  left_join(df, by = "clarity") %>%
  group_by(clarity) %>%
  summarize(p_value = shapiro.test(sample(price, size = min(n(), sample_size)))$p.value)
# Out:
# Warning message in left_join(., df, by = "clarity"):
# "Each row in `x` is expected to match at most 1 row in `y`.
# ℹ Row 1 of `x` matches multiple rows.
# ℹ If multiple matches are expected, set `multiple = "all"` to silence this
#   warning."
#   clarity p_value
# 1 I1      4.452067e-25
# 2 IF      5.133750e-54
# 3 SI1     1.203431e-60
# 4 SI2     1.837361e-58
# 5 VS1     1.743792e-62
# 6 VS2     7.296494e-62
# 7 VVS1    3.256973e-68
# 8 VVS2    5.429093e-68

# %% [markdown]
# #### 設置為相同抽樣 500 個

# %%
df %>%
  group_by(clarity) %>%
  summarize(p_value = shapiro.test(sample(price, size = 500))$p.value)
# Out:
#   clarity p_value
# 1 I1      3.904879e-20
# 2 IF      4.717633e-32
# 3 SI1     1.314105e-23
# 4 SI2     2.773826e-22
# 5 VS1     1.269024e-24
# 6 VS2     9.495861e-25
# 7 VVS1    1.630938e-31
# 8 VVS2    4.168451e-28

# %% [markdown]
# ## 同質性檢查

# %%
library(car)

# %%
leveneTest(price ~ clarity, df)
# Out:
# Warning message in leveneTest.default(y = y, group = group, ...):
# "group coerced to factor."
#       Df    F value  Pr(>F)
# group     7 77.80938 7.584232e-113
#       53932       NA            NA

# %% [markdown]
# # 依照原始資料進行

# %% [markdown]
# ## ANOVA
# ### 不同族群是否有差異?
# * H0: I1 = IF = SI1 = SI2 = VS1 = VS2 = VVS1 = VVS2 = (price)。
# * HA: Otherwise

# %%
# 將clarity轉為因子變數
df$clarity <- factor(df$clarity)

# 以clarity分群，進行ANOVA檢定
anova_result <- aov(price ~ clarity, data = df)

# 顯示ANOVA分析結果
summary(anova_result)
# Out:
#                Df    Sum Sq   Mean Sq F value Pr(>F)
# clarity         7 2.331e+10 3.330e+09     215 <2e-16 ***
# Residuals   53932 8.352e+11 1.549e+07
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1

# %% [markdown]
# ## Follow-up analysis

# %%
result <- TukeyHSD(anova_result, conf.level = 0.95)
result
# Out:
#   Tukey multiple comparisons of means
#     95% family-wise confidence level
#
# Fit: aov(formula = price ~ clarity, data = df)
#
# $clarity
#                    diff         lwr          upr     p adj
# IF-I1     -1059.3295848 -1580.33466  -538.324515 0.0000000
# SI1-I1       71.8324571  -378.57090   522.235816 0.9997320
# SI2-I1     1138.8599147   683.39589  1594.323939 0.0000000
# VS1-I1      -84.7132999  -542.29893   372.872329 0.9992819
# VS2-I1        0.8207037  -450.37770   452.019109 1.0000000
# VVS1-I1   -1401.0540535 -1881.56971  -920.538396 0.0000000
# VVS2-I1    -640.4316203 -1109.53192  -171.331318 0.0009165
# SI1-IF     1131.1620420   830.56369  1431.760399 0.0000000
# SI2-IF     2198.1894995  1890.06020  2506.318797 0.0000000
# VS1-IF      974.6162849   663.35949  1285.873083 0.0000000
# VS2-IF     1060.1502885   758.36197  1361.938605 0.0000000
# VVS1-IF    -341.7244687  -685.80510     2.356168 0.0531204
# VVS2-IF     418.8979645    90.94785   746.848084 0.0027364
# SI2-SI1    1067.0274575   904.66808  1229.386830 0.0000000
# VS1-SI1    -156.5457571  -324.76495    11.673435 0.0899007
# VS2-SI1     -71.0117534  -220.98872    78.965211 0.8410824
# VVS1-SI1  -1472.8865106 -1696.06444 -1249.708586 0.0000000
# VVS2-SI1   -712.2640774  -909.66768  -514.860474 0.0000000
# VS1-SI2   -1223.5732146 -1404.90713 -1042.239301 0.0000000
# VS2-SI2   -1138.0392109 -1302.59127  -973.487148 0.0000000
# VVS1-SI2  -2539.9139681 -2773.13635 -2306.691589 0.0000000
# VVS2-SI2  -1779.2915349 -1987.98383 -1570.599239 0.0000000
# VS2-VS1      85.5340037   -84.80246   255.870471 0.7958312
# VVS1-VS1  -1316.3407535 -1553.67977 -1079.001737 0.0000000
# VVS2-VS1   -555.7183203  -769.00124  -342.435398 0.0000000
# VVS1-VS2  -1401.8747572 -1626.65287 -1177.096640 0.0000000
# VVS2-VS2   -641.2523240  -840.46326  -442.041385 0.0000000
# VVS2-VVS1   760.6224332   501.77828  1019.466585 0.0000000

# %%
plot(result, las = 1, col = "red", cex.axis = 0.5)
# Out:
# Plot with title "95% family-wise confidence level
# "

# %%
# 將 TukeyHSD 結果轉換為資料框
tukey_result <- as.data.frame(result$`clarity`)

# 將比較結果依照差異排序
summary_result <- tukey_result[order(tukey_result$diff), ]

# 顯示排序後的比較結果
summary_result
# Out:
#           diff          lwr         upr          p adj
# VVS1-SI2  -2539.9139681 -2773.13635 -2306.691589 0.000000e+00
# VVS2-SI2  -1779.2915349 -1987.98383 -1570.599239 0.000000e+00
# VVS1-SI1  -1472.8865106 -1696.06444 -1249.708586 0.000000e+00
# VVS1-VS2  -1401.8747572 -1626.65287 -1177.096640 0.000000e+00
# VVS1-I1   -1401.0540535 -1881.56971  -920.538396 6.028511e-14
# VVS1-VS1  -1316.3407535 -1553.67977 -1079.001737 0.000000e+00
# VS1-SI2   -1223.5732146 -1404.90713 -1042.239301 0.000000e+00
# VS2-SI2   -1138.0392109 -1302.59127  -973.487148 0.000000e+00
# IF-I1     -1059.3295848 -1580.33466  -538.324515 2.001534e-08
# VVS2-SI1   -712.2640774  -909.66768  -514.860474 7.693846e-14
# VVS2-VS2   -641.2523240  -840.46326  -442.041385 8.903989e-14
# VVS2-I1    -640.4316203 -1109.53192  -171.331318 9.164598e-04
# VVS2-VS1   -555.7183203  -769.00124  -342.435398 1.940670e-13
# VVS1-IF    -341.7244687  -685.80510     2.356168 5.312042e-02
# VS1-SI1    -156.5457571  -324.76495    11.673435 8.990067e-02
# VS1-I1      -84.7132999  -542.29893   372.872329 9.992819e-01
# VS2-SI1     -71.0117534  -220.98872    78.965211 8.410824e-01
# VS2-I1        0.8207037  -450.37770   452.019109 1.000000e+00
# SI1-I1       71.8324571  -378.57090   522.235816 9.997320e-01
# VS2-VS1      85.5340037   -84.80246   255.870471 7.958312e-01
# VVS2-IF     418.8979645    90.94785   746.848084 2.736376e-03
# VVS2-VVS1   760.6224332   501.77828  1019.466585 5.662137e-14
# VS1-IF      974.6162849   663.35949  1285.873083 6.850076e-14
# VS2-IF     1060.1502885   758.36197  1361.938605 7.593925e-14
# SI2-SI1    1067.0274575   904.66808  1229.386830 0.000000e+00
# SI1-IF     1131.1620420   830.56369  1431.760399 0.000000e+00
# SI2-I1     1138.8599147   683.39589  1594.323939 1.027733e-12
# SI2-IF     2198.1894995  1890.06020  2506.318797 0.000000e+00

# %% [markdown]
# # 全部都抽樣 500 個

# %% [markdown]
# ## ANOVA
# ### 不同族群是否有差異?
# * H0: I1 = IF = SI1 = SI2 = VS1 = VS2 = VVS1 = VVS2 = (price)。
# * HA: Otherwise

# %%
# 數據抽樣
df_sampled <- df %>% group_by(clarity) %>% sample_n(size = 500)

# 將clarity轉變成子變因
df_sampled$clarity <- factor(df_sampled$clarity)

# 以clarity分群，進行ANOVA檢定
sample_anova_result <- aov(price ~ clarity, data = df_sampled)

# 顯示ANOVA分析结果
summary(sample_anova_result)
# Out:
#               Df    Sum Sq   Mean Sq F value Pr(>F)
# clarity        7 2.380e+09 340055191   24.09 <2e-16 ***
# Residuals   3992 5.634e+10  14113113
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1

# %% [markdown]
# ## Follow-up analysis

# %%
sample_result <- TukeyHSD(sample_anova_result, conf.level = 0.95)
sample_result
# Out:
#   Tukey multiple comparisons of means
#     95% family-wise confidence level
#
# Fit: aov(formula = price ~ clarity, data = df_sampled)
#
# $clarity
#                diff        lwr        upr     p adj
# IF-I1     -1165.464 -1885.9765  -444.9515 0.0000267
# SI1-I1      235.600  -484.9125   956.1125 0.9757335
# SI2-I1     1240.844   520.3315  1961.3565 0.0000052
# VS1-I1     -121.734  -842.2465   598.7785 0.9996047
# VS2-I1      105.548  -614.9645   826.0605 0.9998474
# VVS1-I1   -1392.234 -2112.7465  -671.7215 0.0000002
# VVS2-I1    -287.898 -1008.4105   432.6145 0.9287193
# SI1-IF     1401.064   680.5515  2121.5765 0.0000001
# SI2-IF     2406.308  1685.7955  3126.8205 0.0000000
# VS1-IF     1043.730   323.2175  1764.2425 0.0003066
# VS2-IF     1271.012   550.4995  1991.5245 0.0000026
# VVS1-IF    -226.770  -947.2825   493.7425 0.9804840
# VVS2-IF     877.566   157.0535  1598.0785 0.0054971
# SI2-SI1    1005.244   284.7315  1725.7565 0.0006273
# VS1-SI1    -357.334 -1077.8465   363.1785 0.8056234
# VS2-SI1    -130.052  -850.5645   590.4605 0.9993886
# VVS1-SI1  -1627.834 -2348.3465  -907.3215 0.0000000
# VVS2-SI1   -523.498 -1244.0105   197.0145 0.3498015
# VS1-SI2   -1362.578 -2083.0905  -642.0655 0.0000003
# VS2-SI2   -1135.296 -1855.8085  -414.7835 0.0000501
# VVS1-SI2  -2633.078 -3353.5905 -1912.5655 0.0000000
# VVS2-SI2  -1528.742 -2249.2545  -808.2295 0.0000000
# VS2-VS1     227.282  -493.2305   947.7945 0.9802294
# VVS1-VS1  -1270.500 -1991.0125  -549.9875 0.0000026
# VVS2-VS1   -166.164  -886.6765   554.3485 0.9970304
# VVS1-VS2  -1497.782 -2218.2945  -777.2695 0.0000000
# VVS2-VS2   -393.446 -1113.9585   327.0665 0.7158058
# VVS2-VVS1  1104.336   383.8235  1824.8485 0.0000940

# %%
plot(sample_result, las = 1, col = "red", cex.axis = 0.5)
# Out:
# Plot with title "95% family-wise confidence level
# "

# %%
# 將 TukeyHSD 結果轉換為資料框
sample_tukey_result <- as.data.frame(sample_result$`clarity`)

# 將比較結果依照差異排序
sample_summary_result <- sample_tukey_result[order(sample_tukey_result$diff), ]

# 顯示排序後的比較結果
sample_summary_result
# Out:
#           diff      lwr        upr        p adj
# VVS1-SI2  -2633.078 -3353.5905 -1912.5655 2.472674e-08
# VVS1-SI1  -1627.834 -2348.3465  -907.3215 2.496311e-08
# VVS2-SI2  -1528.742 -2249.2545  -808.2295 2.860983e-08
# VVS1-VS2  -1497.782 -2218.2945  -777.2695 3.372672e-08
# VVS1-I1   -1392.234 -2112.7465  -671.7215 1.646325e-07
# VS1-SI2   -1362.578 -2083.0905  -642.0655 3.170303e-07
# VVS1-VS1  -1270.500 -1991.0125  -549.9875 2.640853e-06
# IF-I1     -1165.464 -1885.9765  -444.9515 2.665647e-05
# VS2-SI2   -1135.296 -1855.8085  -414.7835 5.005219e-05
# VVS2-SI1   -523.498 -1244.0105   197.0145 3.498015e-01
# VVS2-VS2   -393.446 -1113.9585   327.0665 7.158058e-01
# VS1-SI1    -357.334 -1077.8465   363.1785 8.056234e-01
# VVS2-I1    -287.898 -1008.4105   432.6145 9.287193e-01
# VVS1-IF    -226.770  -947.2825   493.7425 9.804840e-01
# VVS2-VS1   -166.164  -886.6765   554.3485 9.970304e-01
# VS2-SI1    -130.052  -850.5645   590.4605 9.993886e-01
# VS1-I1     -121.734  -842.2465   598.7785 9.996047e-01
# VS2-I1      105.548  -614.9645   826.0605 9.998474e-01
# VS2-VS1     227.282  -493.2305   947.7945 9.802294e-01
# SI1-I1      235.600  -484.9125   956.1125 9.757335e-01
# VVS2-IF     877.566   157.0535  1598.0785 5.497106e-03
# SI2-SI1    1005.244   284.7315  1725.7565 6.272777e-04
# VS1-IF     1043.730   323.2175  1764.2425 3.066146e-04
# VVS2-VVS1  1104.336   383.8235  1824.8485 9.396181e-05
# SI2-I1     1240.844   520.3315  1961.3565 5.161345e-06
# VS2-IF     1271.012   550.4995  1991.5245 2.610210e-06
# SI1-IF     1401.064   680.5515  2121.5765 1.367474e-07
# SI2-IF     2406.308  1685.7955  3126.8205 2.472678e-08
