# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager

# 指定中文字型路徑
font_path = 'C:\Windows\Fonts\msjh.ttc'

# 載入字型
prop = font_manager.FontProperties(fname=font_path)

# 設定中文字型為預設字型
plt.rcParams['font.sans-serif'] = prop.get_name()

# %%
import pandas as pd

df = pd.read_csv('./影響中山大學學生零用金的因素- (回覆)公開版 - 表單回應 1.csv')
df
# Out:
#                      時間戳記 您目前就讀幾年級? 您目前就讀中山大學哪一個學院? 生理性別  年紀 目前住宿地點
# 0    2023/4/21 下午 6:26:51        大二             理學院   男性  20   校內宿舍  \
# 1    2023/4/21 下午 6:27:15        大二             文學院   女性  24   校內宿舍
# 2    2023/4/21 下午 6:30:08        大二            商管學院   男性  21   校內宿舍
# 3    2023/4/21 下午 6:30:23        大一           海洋科學院   女性  18   校內宿舍
# 4    2023/4/21 下午 6:31:11        大二            商管學院   男性  20   校內宿舍
# ..                    ...       ...             ...  ...  ..    ...
# 251  2023/5/8 下午 10:00:19        大二            商管學院   女性  21   校內宿舍
# 252  2023/5/8 下午 10:24:30        大四           社會科學院   男性  22     家裡
# 253  2023/5/11 上午 1:33:58        大四            商管學院   女性  22   校內宿舍
# 254  2023/5/11 下午 3:48:43        大四           社會科學院   男性  22     家裡
# 255  2023/5/12 下午 2:47:19        大四             文學院   女性  22   校內宿舍
#
#          目前有打工嗎? 主要交通方式 家鄉 (上大學前居住最久的區域)  你認為自己的個性呢?  ...
# 0             沒有     機車               南部           5  ...  \
# 1             沒有     機車               國外           2  ...
# 2              有   大眾運輸               國外           3  ...
# 3             沒有     機車               南部           2  ...
# 4              有     機車               北部           4  ...
# ..           ...    ...              ...         ...  ...
# 251  現在沒有，但需要去打工   大眾運輸               國外           3  ...
# 252            有     機車               南部           3  ...
# 253            有     機車               南部           2  ...
# 254           沒有     汽車               南部           3  ...
# 255            有   大眾運輸               南部           4  ...
#
#      每個月可以存多少錢?  *單位: 新台幣 住宿房租於零用金的 大約 佔比 餐費於零用金的 大約 佔比 過去兩周內，各類單筆 最高消費。 [餐費]
# 0                 1000元以下               0             8                 200以下  \
# 1              2001-3000元               0             4               201-350
# 2              1001-2000元               4             4               201-350
# 3                 1000元以下               0             7                 200以下
# 4              1001-2000元               3             3                1150以上
# ..                    ...             ...           ...                   ...
# 251               1000元以下               3             4              751-1000
# 252               1000元以下               0            10               201-350
# 253            1001-2000元               3             6                1150以上
# 254               1000元以下               2             5                1150以上
# 255            1001-2000元               0             4             1001-1150
#
#     過去兩周內，各類單筆 最高消費。 [娛樂費] 過去兩周內，各類單筆 最高消費。 [治裝費] 過去兩周內，各類單筆 最高消費。 [書籍費]
# 0                    200以下                  200以下                  200以下  \
# 1                  201-350               751-1000                  200以下
# 2                  201-350                  200以下                  200以下
# 3                    200以下                  200以下                  200以下
# 4                   1150以上                 1150以上                  200以下
# ..                     ...                    ...                    ...
# 251                201-350                  200以下                  200以下
# 252                  200以下                  200以下                  200以下
# 253                  200以下                  200以下                 1150以上
# 254                201-350                  200以下                  200以下
# 255                201-350               751-1000                501-750
#
#     就您的體感，目前的零用金夠嗎 同上，請就您的體感，目前的零用金夠嗎                             您的電子信箱
# 0                夠                  5            william710651@gmail.com
# 1                夠                  4               szerica888@gmail.com
# 2                夠                  4             linliang1113@gmail.com
# 3       再多1000以下足夠                  3            s2622287dolly@gmail.com
# 4                夠                  5  edwardchiu168@g-mail.nsysu.edu.tw
# ..             ...                ...                                ...
# 251      需再多1000以上                  1         christineczq0209@gmail.com
# 252      需再多1000以上                  1               kh20001219@gmail.com
# 253              夠                  5            qazwsxed43212@gmail.com
# 254              夠                  5             wade90050315@gmail.com
# 255              夠                  4              a0922098657@gmail.com
#
# [256 rows x 65 columns]

# %%
df.columns
# Out:
# Index(['時間戳記', '您目前就讀幾年級?', '您目前就讀中山大學哪一個學院?', '生理性別', '年紀', '目前住宿地點',
#        '目前有打工嗎?', '主要交通方式', '家鄉 (上大學前居住最久的區域)', '你認為自己的個性呢?',
#        '目前一個月 的零用金 全部 有多少呢?  \n*單位: 新台幣',
#        '同上，目前一個月 的零用金 全部 有多少呢?  \n*單位: 新台幣\n(落在以下哪一個區間)',
#        '每月全部的零用金中，來自 家庭 的金額  \n*單位: 新台幣', '每月全部的零用金中，來自 打工 的金額  \n*單位: 新台幣',
#        '每月全部的零用金中，來自 學貸 的金額  \n*單位: 新台幣', '每月全部的零用金中，來自 各類補助 的金額  \n*單位: 新台幣',
#        '每月全部的零用金中，透支 的金額  \n*單位: 新台幣', '家庭經濟狀況', '家庭工作狀況', '父母年紀 [父]',
#        '父母年紀 [母]', '父母親教育程度 [父]', '父母親教育程度 [母]', '父母工作類別 [父]', '父母工作類別 [母]',
#        '父母經歷 [父]', '父母經歷 [母]', '兄弟姊妹數量', '家庭教育模式 [父]', '家庭教育模式 [母]',
#        '父母消費消費習慣 [父]', '父母消費消費習慣 [母]', '高中前(含)- 零用金模式', '現在與家人的有效溝通程度',
#        '住在家裡時，與家人的一起用餐頻率', '住在家裡時，與家人的一起出遊頻率', '家庭金錢觀念', '您自己的成長歷程',
#        '您家庭成員的成長歷程', '大學學雜費', '您的家庭所提供零用金的金額主要是由誰所決定?',
#        '您的家庭所提供零用金的數量主要是由誰所提供?', '您有提出過要調整零用金的金額嗎？', '家人支持您打工嗎？',
#        '您的每月家庭所提供零用金金額是固定的嗎?', '父母星座 [父]', '父母星座 [母]', '父母星座 [自己]', '家庭網路購物頻率',
#        '家庭成員喜歡/擅長的運動', '您曾學習過的才藝/課外課程', '您目前就讀的校系有符合父母的期望嗎?', '家庭有要求讀研究所嗎?',
#        '家庭對您感情狀況的態度?', '上學期 GPA', '每個月可以存多少錢?  *單位: 新台幣', '住宿房租於零用金的 大約 佔比',
#        '餐費於零用金的 大約 佔比', '過去兩周內，各類單筆 最高消費。 [餐費]', '過去兩周內，各類單筆 最高消費。 [娛樂費]',
#        '過去兩周內，各類單筆 最高消費。 [治裝費]', '過去兩周內，各類單筆 最高消費。 [書籍費]', '就您的體感，目前的零用金夠嗎',
#        '同上，請就您的體感，目前的零用金夠嗎', '您的電子信箱'],
#       dtype='object')

# %% [markdown]
# # 針對經濟狀況

# %%
# 計算每個家庭經濟狀況描述的出現頻率
economy_counts = df['家庭經濟狀況'].value_counts()
print("家庭經濟狀況頻率:")
economy_counts
# Out:
# 家庭經濟狀況頻率:
# 家庭經濟狀況
# 普通偏上    103
# 小康      101
# 普通偏下     44
# 清寒        6
# 富裕        2
# Name: count, dtype: int64

# %%
# 比較不同家庭經濟狀況的受訪者之間的零用金水平
economy_groups = df.groupby('家庭經濟狀況')
average_allowance = economy_groups['目前一個月 的零用金 全部 有多少呢?  \n*單位: 新台幣'].mean()
print("不同家庭經濟狀況的平均零用金:")
average_allowance
# Out:
# 不同家庭經濟狀況的平均零用金:
# 家庭經濟狀況
# 富裕      14000.000000
# 小康      13349.504950
# 普通偏上    12717.475728
# 普通偏下    12832.727273
# 清寒       8500.000000
# Name: 目前一個月 的零用金 全部 有多少呢?  \n*單位: 新台幣, dtype: float64

# %%
plt.figure(figsize=(10, 6))
df.boxplot(column='目前一個月 的零用金 全部 有多少呢?  \n*單位: 新台幣', by='家庭經濟狀況')
plt.xlabel('家庭經濟狀況')
plt.ylabel('目前一個月的零用金全部有多少呢? (新台幣)')
plt.title('家庭經濟狀況對目前零用金的影響')
plt.suptitle('')  # 移除預設的子標題
plt.show()

# %%
from scipy.stats import shapiro

for name, group in df[df['家庭經濟狀況'] != '富裕'].groupby('家庭經濟狀況'):
    stat, p_value = shapiro(group['目前一個月 的零用金 全部 有多少呢?  \n*單位: 新台幣'])
    print(f"家庭經濟狀況: {name}")
    print("Shapiro-Wilk test統計量:", stat)
    print("p值:", p_value)
    print()
# Out:
# 家庭經濟狀況: 小康
# Shapiro-Wilk test統計量: 0.8064631223678589
# p值: 3.424521222150645e-10
#
# 家庭經濟狀況: 普通偏上
# Shapiro-Wilk test統計量: 0.8652456998825073
# p值: 3.1833742752951366e-08
#
# 家庭經濟狀況: 普通偏下
# Shapiro-Wilk test統計量: 0.5878927111625671
# p值: 6.710934585818507e-10
#
# 家庭經濟狀況: 清寒
# Shapiro-Wilk test統計量: 0.6842072010040283
# p值: 0.004195825662463903

# %%
from scipy.stats import bartlett

# 獨立性檢定 - Bartlett's test
data = [group['目前一個月 的零用金 全部 有多少呢?  \n*單位: 新台幣'] for name, group in df.groupby('家庭經濟狀況')]
stat, p_value = bartlett(*data)
print("Bartlett's test統計量:", stat)
print("p值:", p_value)
# Out:
# Bartlett's test統計量: 40.16170485953736
# p值: 4.00760367289135e-08

# %%
from scipy.stats import kruskal

# 提取每個群組的零用金資料
data = [group['目前一個月 的零用金 全部 有多少呢?  \n*單位: 新台幣'] for name, group in df.groupby('家庭經濟狀況')]

# 進行Kruskal-Wallis檢定
stat, p_value = kruskal(*data)

# 輸出檢定結果
print("Kruskal-Wallis檢定結果:")
print("統計量:", stat)
print("p值:", p_value)
# Out:
# Kruskal-Wallis檢定結果:
# 統計量: 7.135382493445048
# p值: 0.12890451182535823

# %%
import pandas as pd
from scipy.stats import mannwhitneyu

# 進行兩兩比較的事後分析
groups = df.groupby('家庭經濟狀況')

# 建立空的資料框架
results_df = pd.DataFrame(columns=['Group 1', 'Group 2', 'Mann-Whitney U statistic', 'p-value'])

# 進行多重比較
for name1, group1 in groups:
    for name2, group2 in groups:
        if name1 < name2:  # 避免重複比較
            statistic, p_value = mannwhitneyu(group1['目前一個月 的零用金 全部 有多少呢?  \n*單位: 新台幣'], group2['目前一個月 的零用金 全部 有多少呢?  \n*單位: 新台幣'])

            # 將結果加入資料框架
            results_df = pd.concat([results_df, pd.DataFrame({'Group 1': [name1], 'Group 2': [name2], 'Mann-Whitney U statistic': [statistic], 'p-value': [p_value]})])

# 重新設定索引
results_df = results_df.reset_index(drop=True)

# 顯示資料框架
results_df
# Out:
#   Group 1 Group 2  Mann-Whitney U statistic   p-value
# 0      富裕      小康                     137.5  0.384058
# 1      富裕    普通偏上                     141.5  0.368184
# 2      富裕    普通偏下                      63.5  0.305123
# 3      富裕      清寒                      12.0  0.050786
# 4      小康    普通偏上                    5317.5  0.781712
# 5      小康    普通偏下                    2609.5  0.094023
# 6      小康      清寒                     443.5  0.054350
# 7    普通偏上    普通偏下                    2619.0  0.133822
# 8    普通偏上      清寒                     448.0  0.062309
# 9    普通偏下      清寒                     161.5  0.385210

# %% [markdown]
# # 打工狀態

# %%
# 計算每個打工狀態的出現頻率
employment_counts = df['目前有打工嗎?'].value_counts()
print("目前有打工頻率:")
employment_counts
# Out:
# 目前有打工頻率:
# 目前有打工嗎?
# 有              104
# 沒有              90
# 曾經有，現在沒有        54
# 現在沒有，但需要去打工      8
# Name: count, dtype: int64

# %%
average_allowance_by_employment = df.groupby('目前有打工嗎?')['目前一個月 的零用金 全部 有多少呢?  \n*單位: 新台幣'].mean()
average_allowance_by_employment
# Out:
# 目前有打工嗎?
# 曾經有，現在沒有       11133.333333
# 有              16314.807692
# 沒有             10560.000000
# 現在沒有，但需要去打工     6687.500000
# Name: 目前一個月 的零用金 全部 有多少呢?  \n*單位: 新台幣, dtype: float64

# %%
plt.figure(figsize=(10, 6))
df.boxplot(column='目前一個月 的零用金 全部 有多少呢?  \n*單位: 新台幣', by='目前有打工嗎?')
plt.xlabel('目前有打工嗎?')
plt.ylabel('目前一個月的零用金全部有多少呢? (新台幣)')
plt.title('家庭經濟狀況對目前零用金的影響')
plt.suptitle('')  # 移除預設的子標題
plt.show()

# %%
from scipy.stats import shapiro

for name, group in df.groupby('目前有打工嗎?'):
    stat, p_value = shapiro(group['目前一個月 的零用金 全部 有多少呢?  \n*單位: 新台幣'])
    print(f"目前有打工嗎?: {name}")
    print("Shapiro-Wilk test統計量:", stat)
    print("p值:", p_value)
    print()
# Out:
# 目前有打工嗎?: 曾經有，現在沒有
# Shapiro-Wilk test統計量: 0.8055275082588196
# p值: 5.527637654267892e-07
#
# 目前有打工嗎?: 有
# Shapiro-Wilk test統計量: 0.7522983551025391
# p值: 5.910363778255379e-12
#
# 目前有打工嗎?: 沒有
# Shapiro-Wilk test統計量: 0.8115140795707703
# p值: 2.3053330355793378e-09
#
# 目前有打工嗎?: 現在沒有，但需要去打工
# Shapiro-Wilk test統計量: 0.8645768165588379
# p值: 0.13331513106822968

# %%
from scipy.stats import bartlett

# 獨立性檢定 - Bartlett's test
data = [group['目前一個月 的零用金 全部 有多少呢?  \n*單位: 新台幣'] for name, group in df.groupby('目前有打工嗎?')]
stat, p_value = bartlett(*data)
print("Bartlett's test統計量:", stat)
print("p值:", p_value)
# Out:
# Bartlett's test統計量: 70.23930795608452
# p值: 3.793275429898817e-15

# %%
from scipy.stats import kruskal

# 提取每個群組的零用金資料
data = [group['目前一個月 的零用金 全部 有多少呢?  \n*單位: 新台幣'] for name, group in df.groupby('目前有打工嗎?')]

# 進行Kruskal-Wallis檢定
stat, p_value = kruskal(*data)

# 輸出檢定結果
print("Kruskal-Wallis檢定結果:")
print("統計量:", stat)
print("p值:", p_value)
# Out:
# Kruskal-Wallis檢定結果:
# 統計量: 46.55274557620209
# p值: 4.3267119360973864e-10

# %% [markdown]
# 進行Kruskal-Wallis檢定後，不同組別之間存在統計上的顯著差異，事後分析方法進行多重比較，以比較所有可能的組合。者李使用Mann-Whitney U檢定

# %%
import pandas as pd
from scipy.stats import mannwhitneyu

# 進行兩兩比較的事後分析
groups = df.groupby('目前有打工嗎?')

# 建立空的資料框架
results_df = pd.DataFrame(columns=['Group 1', 'Group 2', 'Mann-Whitney U statistic', 'p-value'])

# 進行多重比較
for name1, group1 in groups:
    for name2, group2 in groups:
        if name1 < name2:  # 避免重複比較
            statistic, p_value = mannwhitneyu(group1['目前一個月 的零用金 全部 有多少呢?  \n*單位: 新台幣'], group2['目前一個月 的零用金 全部 有多少呢?  \n*單位: 新台幣'])

            # 將結果加入資料框架
            results_df = pd.concat([results_df, pd.DataFrame({'Group 1': [name1], 'Group 2': [name2], 'Mann-Whitney U statistic': [statistic], 'p-value': [p_value]})])

# 重新設定索引
results_df = results_df.reset_index(drop=True)

# 顯示資料框架
results_df
# Out:
#     Group 1      Group 2  Mann-Whitney U statistic       p-value
# 0  曾經有，現在沒有            有                    1639.5  1.700923e-05
# 1  曾經有，現在沒有           沒有                    2508.5  7.423549e-01
# 2  曾經有，現在沒有  現在沒有，但需要去打工                     342.5  7.255615e-03
# 3         有           沒有                    6871.5  1.543369e-08
# 4         有  現在沒有，但需要去打工                     749.5  1.635138e-04
# 5        沒有  現在沒有，但需要去打工                     565.0  6.795988e-03

# %% [markdown]
# # 家鄉

# %%
# 計算每個打工狀態的出現頻率
home_city_counts = df['家鄉 (上大學前居住最久的區域)'].value_counts()
print("居住地頻率:")
home_city_counts
# Out:
# 居住地頻率:
# 家鄉 (上大學前居住最久的區域)
# 北部    103
# 南部     84
# 中部     44
# 國外     22
# 東部      3
# Name: count, dtype: int64

# %%
average_allowance_home_city = df.groupby('家鄉 (上大學前居住最久的區域)')['目前一個月 的零用金 全部 有多少呢?  \n*單位: 新台幣'].mean()
average_allowance_home_city
# Out:
# 家鄉 (上大學前居住最久的區域)
# 中部    12463.636364
# 北部    13721.359223
# 南部    12162.380952
# 國外    12931.818182
# 東部    11333.333333
# Name: 目前一個月 的零用金 全部 有多少呢?  \n*單位: 新台幣, dtype: float64

# %%
plt.figure(figsize=(10, 6))
df.boxplot(column='目前一個月 的零用金 全部 有多少呢?  \n*單位: 新台幣', by='家鄉 (上大學前居住最久的區域)')
plt.xlabel('家鄉 (上大學前居住最久的區域)')
plt.ylabel('目前一個月的零用金全部有多少呢? (新台幣)')
plt.title('家庭經濟狀況對目前零用金的影響')
plt.suptitle('')  # 移除預設的子標題
plt.show()

# %%
from scipy.stats import shapiro

for name, group in df.groupby('家鄉 (上大學前居住最久的區域)'):
    stat, p_value = shapiro(group['目前一個月 的零用金 全部 有多少呢?  \n*單位: 新台幣'])
    print(f"家鄉 (上大學前居住最久的區域): {name}")
    print("Shapiro-Wilk test統計量:", stat)
    print("p值:", p_value)
    print()
# Out:
# 家鄉 (上大學前居住最久的區域): 中部
# Shapiro-Wilk test統計量: 0.9573245644569397
# p值: 0.10334208607673645
#
# 家鄉 (上大學前居住最久的區域): 北部
# Shapiro-Wilk test統計量: 0.7759761214256287
# p值: 3.125611922061289e-11
#
# 家鄉 (上大學前居住最久的區域): 南部
# Shapiro-Wilk test統計量: 0.6119471788406372
# p值: 1.4436172255435226e-13
#
# 家鄉 (上大學前居住最久的區域): 國外
# Shapiro-Wilk test統計量: 0.8847939968109131
# p值: 0.014932896941900253
#
# 家鄉 (上大學前居住最久的區域): 東部
# Shapiro-Wilk test統計量: 0.8546513319015503
# p值: 0.25296899676322937

# %%
from scipy.stats import bartlett

# 獨立性檢定 - Bartlett's test
data = [group['目前一個月 的零用金 全部 有多少呢?  \n*單位: 新台幣'] for name, group in df.groupby('家鄉 (上大學前居住最久的區域)')]
stat, p_value = bartlett(*data)
print("Bartlett's test統計量:", stat)
print("p值:", p_value)
# Out:
# Bartlett's test統計量: 31.421712849452497
# p值: 2.5110794658306144e-06

# %%
from scipy.stats import kruskal

# 提取每個群組的零用金資料
data = [group['目前一個月 的零用金 全部 有多少呢?  \n*單位: 新台幣'] for name, group in df.groupby('家鄉 (上大學前居住最久的區域)')]

# 進行Kruskal-Wallis檢定
stat, p_value = kruskal(*data)

# 輸出檢定結果
print("Kruskal-Wallis檢定結果:")
print("統計量:", stat)
print("p值:", p_value)
# Out:
# Kruskal-Wallis檢定結果:
# 統計量: 12.791076048019807
# p值: 0.012343061750119963

# %%
import pandas as pd
from scipy.stats import mannwhitneyu

# 進行兩兩比較的事後分析
groups = df.groupby('家鄉 (上大學前居住最久的區域)')

# 建立空的資料框架
results_df = pd.DataFrame(columns=['Group 1', 'Group 2', 'Mann-Whitney U statistic', 'p-value'])

# 進行多重比較
for name1, group1 in groups:
    for name2, group2 in groups:
        if name1 < name2:  # 避免重複比較
            statistic, p_value = mannwhitneyu(group1['目前一個月 的零用金 全部 有多少呢?  \n*單位: 新台幣'], group2['目前一個月 的零用金 全部 有多少呢?  \n*單位: 新台幣'])

            # 將結果加入資料框架
            results_df = pd.concat([results_df, pd.DataFrame({'Group 1': [name1], 'Group 2': [name2], 'Mann-Whitney U statistic': [statistic], 'p-value': [p_value]})])

# 重新設定索引
results_df = results_df.reset_index(drop=True)

# 顯示資料框架
results_df
# Out:
#   Group 1 Group 2  Mann-Whitney U statistic   p-value
# 0      中部      北部                    2216.5  0.833770
# 1      中部      南部                    2309.5  0.020006
# 2      中部      國外                     526.0  0.568666
# 3      中部      東部                      83.0  0.468950
# 4      北部      南部                    5583.0  0.000579
# 5      北部      國外                    1282.0  0.329274
# 6      北部      東部                     208.0  0.306333
# 7      南部      國外                     821.5  0.424303
# 8      南部      東部                     136.0  0.824199
# 9      國外      東部                      38.5  0.673481

# %% [markdown]
# # 探討經濟，打工與家鄉對零用金影響

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder

# 選擇要使用的變數
variables = ['家鄉 (上大學前居住最久的區域)', '目前有打工嗎?', '家庭經濟狀況']

# 提取相關的欄位資料
data = df[variables + ['目前一個月 的零用金 全部 有多少呢?  \n*單位: 新台幣']]

# 檢查缺失值
print(data.isnull().sum())

# 處理缺失值
data = data.dropna()

# 轉換類別變數為獨熱編碼
onehot_encoder = OneHotEncoder(sparse=False)
X_encoded = onehot_encoder.fit_transform(data[variables])
# Out:
# 家鄉 (上大學前居住最久的區域)                   0
# 目前有打工嗎?                            0
# 家庭經濟狀況                             0
# 目前一個月 的零用金 全部 有多少呢?  \n*單位: 新台幣    0
# dtype: int64
# C:\Users\eddie\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
# 分割自變數和應變數
X = X_encoded
y = data['目前一個月 的零用金 全部 有多少呢?  \n*單位: 新台幣']

# 建立線性迴歸模型
model = LinearRegression()

# 擬合模型
model.fit(X, y)

# 顯示迴歸係數和截距
print("迴歸係數:")
print(model.coef_)
print("截距:")
print(model.intercept_)
# Out:
# 迴歸係數:
# [ 4.51674122e+17  4.51674122e+17  4.51674122e+17  4.51674122e+17
#   4.51674122e+17  2.44220053e+16  2.44220053e+16  2.44220053e+16
#   2.44220053e+16 -8.39308041e+17 -8.39308041e+17 -8.39308041e+17
#  -8.39308041e+17 -8.39308041e+17]
# 截距:
# 3.632119133210998e+17

# %%
from sklearn.metrics import r2_score, mean_squared_error
# 進行預測
y_pred = model.predict(X)

# 計算R平方
r2 = r2_score(y, y_pred)
print("R平方:", r2)

# 計算均方誤差(MSE)
mse = mean_squared_error(y, y_pred)
print("均方誤差(MSE):", mse)
# Out:
# R平方: 0.16427970169585382
# 均方誤差(MSE): 51004846.75

# %%
# 繪製散點圖和回歸線
plt.scatter(y, y_pred)
plt.plot([y.min(), y.max()], [y.min(), y.max()], '--', color='red', linewidth=2)
plt.xlabel('實際零用金')
plt.ylabel('預測零用金')
plt.title('實際值 vs. 預測值')
plt.show()
