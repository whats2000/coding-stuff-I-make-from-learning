# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ### Example: Restaurant Tipping

# %%
tips = pd.read_csv('tips.csv')
tips
# Out:
#      total_bill   tip smoker   day    time  size
# 0         16.99  1.01     No   Sun  Dinner     2
# 1         10.34  1.66     No   Sun  Dinner     3
# 2         21.01  3.50     No   Sun  Dinner     3
# 3         23.68  3.31     No   Sun  Dinner     2
# 4         24.59  3.61     No   Sun  Dinner     4
# ..          ...   ...    ...   ...     ...   ...
# 239       29.03  5.92     No   Sat  Dinner     3
# 240       27.18  2.00    Yes   Sat  Dinner     2
# 241       22.67  2.00    Yes   Sat  Dinner     2
# 242       17.82  1.75     No   Sat  Dinner     2
# 243       18.78  3.00     No  Thur  Dinner     2
#
# [244 rows x 6 columns]

# %%
party_pcts = party_counts.div(party_counts.sum(1),axis="rows")
party_pcts
# Out:
# size         1         2         3         4         5         6
# day
# Fri   0.052632  0.842105  0.052632  0.052632  0.000000  0.000000
# Sat   0.022989  0.609195  0.206897  0.149425  0.011494  0.000000
# Sun   0.000000  0.513158  0.197368  0.236842  0.039474  0.013158
# Thur  0.016129  0.774194  0.064516  0.080645  0.016129  0.048387

# %%
party_counts = pd.crosstab(tips['day'],tips['size'])
party_counts
# Out:
# size  1   2   3   4  5  6
# day
# Fri   1  16   1   1  0  0
# Sat   2  53  18  13  1  0
# Sun   0  39  15  18  3  1
# Thur  1  48   4   5  1  3

# %%
party_counts.plot.bar()
# Out:
# <AxesSubplot:xlabel='day'>

# %% [markdown]
# ### Example: Tipping percentage by day with seaborn

# %%
import seaborn as sns

# %%
tips
# Out:
#      total_bill   tip smoker   day    time  size
# 0         16.99  1.01     No   Sun  Dinner     2
# 1         10.34  1.66     No   Sun  Dinner     3
# 2         21.01  3.50     No   Sun  Dinner     3
# 3         23.68  3.31     No   Sun  Dinner     2
# 4         24.59  3.61     No   Sun  Dinner     4
# ..          ...   ...    ...   ...     ...   ...
# 239       29.03  5.92     No   Sat  Dinner     3
# 240       27.18  2.00    Yes   Sat  Dinner     2
# 241       22.67  2.00    Yes   Sat  Dinner     2
# 242       17.82  1.75     No   Sat  Dinner     2
# 243       18.78  3.00     No  Thur  Dinner     2
#
# [244 rows x 6 columns]

# %%
tips['tip_pct'] = tips['tip']/(tips['total_bill']-tips['tip'])
tips
# Out:
#      total_bill   tip smoker   day    time  size   tip_pct
# 0         16.99  1.01     No   Sun  Dinner     2  0.063204
# 1         10.34  1.66     No   Sun  Dinner     3  0.191244
# 2         21.01  3.50     No   Sun  Dinner     3  0.199886
# 3         23.68  3.31     No   Sun  Dinner     2  0.162494
# 4         24.59  3.61     No   Sun  Dinner     4  0.172069
# ..          ...   ...    ...   ...     ...   ...       ...
# 239       29.03  5.92     No   Sat  Dinner     3  0.256166
# 240       27.18  2.00    Yes   Sat  Dinner     2  0.079428
# 241       22.67  2.00    Yes   Sat  Dinner     2  0.096759
# 242       17.82  1.75     No   Sat  Dinner     2  0.108899
# 243       18.78  3.00     No  Thur  Dinner     2  0.190114
#
# [244 rows x 7 columns]

# %%
sns.barplot(x = 'tip_pct', y = 'day', data=tips, orient='h')
# Out:
# <AxesSubplot:xlabel='tip_pct', ylabel='day'>

# %%
# Hue enables the split by an additional categorial value
sns.barplot(x = 'tip_pct', y = 'day',hue="time", data=tips, orient='h')
# Out:
# <AxesSubplot:xlabel='tip_pct', ylabel='day'>

# %%
tips
# Out:
#      total_bill   tip smoker   day    time  size   tip_pct
# 0         16.99  1.01     No   Sun  Dinner     2  0.063204
# 1         10.34  1.66     No   Sun  Dinner     3  0.191244
# 2         21.01  3.50     No   Sun  Dinner     3  0.199886
# 3         23.68  3.31     No   Sun  Dinner     2  0.162494
# 4         24.59  3.61     No   Sun  Dinner     4  0.172069
# ..          ...   ...    ...   ...     ...   ...       ...
# 239       29.03  5.92     No   Sat  Dinner     3  0.256166
# 240       27.18  2.00    Yes   Sat  Dinner     2  0.079428
# 241       22.67  2.00    Yes   Sat  Dinner     2  0.096759
# 242       17.82  1.75     No   Sat  Dinner     2  0.108899
# 243       18.78  3.00     No  Thur  Dinner     2  0.190114
#
# [244 rows x 7 columns]

# %% [markdown]
# ### Histogram Plot
# - Histogram in a kind of bar plot that gives discretized display of values frequency
# - The towers of bars of a histogram are called bins
# - The height of each bin shows how many values from that data fall into that range

# %%
tips['tip_pct'].plot.hist(bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
tips['tip_pct'].min()
# Out:
# 0.03695514845230575

# %%
tips['tip_pct'].max()

# %% [markdown]
# ### Density plot of tips percentage
# - Density plot is formed by computing an estimate of continuous probability distributions
# - Density plos are also know as kernel density mixture

# %%
tips['tip_pct'].plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ### Seaborn: Example of histogram and density plot

# %%
comp1 = np.random.normal(0, 1, size=200)
# The value mean = 0 std = 1 and size is 200 which is normal distributed

# %%
comp2 = np.random.normal(10, 2, size=200)
comp3 = np.random.normal(10, 2, size=10)

# %%
comp3
# Out:
# array([ 5.71953364, 11.95160058, 12.84140027,  9.65079115, 11.67487091,
#         8.95742706,  8.79242996,  9.50278913, 13.12860109, 11.77821039])

# %%
values = pd.Series(np.concatenate([comp1, comp2]))
sns.displot(values, bins=100, color='g')

# %%
sns.displot(values, bins=100, color='g', kde=True)

# %% [markdown]
# - Another way of creating histogram and density plot is by using `histplot`

# %%
sns.histplot(values, bins=100, color='b', kde=True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# ### Scatter plot or point plot

# %%
macro = pd.read_csv('macrodata.csv')
macro
# Out:
#      year  quarter    realgdp  realcons   realinv  realgovt  realdpi      cpi  \
# 0    1959        1   2710.349    1707.4   286.898   470.045   1886.9   28.980
# 1    1959        2   2778.801    1733.7   310.859   481.301   1919.7   29.150
# 2    1959        3   2775.488    1751.8   289.226   491.260   1916.4   29.350
# 3    1959        4   2785.204    1753.7   299.356   484.052   1931.3   29.370
# 4    1960        1   2847.699    1770.5   331.722   462.199   1955.5   29.540
# ..    ...      ...        ...       ...       ...       ...      ...      ...
# 198  2008        3  13324.600    9267.7  1990.693   991.551   9838.3  216.889
# 199  2008        4  13141.920    9195.3  1857.661  1007.273   9920.4  212.174
# 200  2009        1  12925.410    9209.2  1558.494   996.287   9926.4  212.671
# 201  2009        2  12901.504    9189.0  1456.678  1023.528  10077.5  214.469
# 202  2009        3  12990.341    9256.0  1486.398  1044.088  10040.6  216.385
#
# ...

# %% [markdown]
# - CPI: consumer price index
# - m1: nominal money stock
# - tbilrate: 3-month treasure bill
# - umemp: unemployment rate

# %%
data = macro[['cpi', 'm1', 'tbilrate', 'unemp']]
data
# Out:
#          cpi      m1  tbilrate  unemp
# 0     28.980   139.7      2.82    5.8
# 1     29.150   141.7      3.08    5.1
# 2     29.350   140.5      3.82    5.3
# 3     29.370   140.0      4.33    5.6
# 4     29.540   139.6      3.50    5.2
# ..       ...     ...       ...    ...
# 198  216.889  1474.7      1.17    6.0
# 199  212.174  1576.5      0.12    6.9
# 200  212.671  1592.8      0.22    8.1
# 201  214.469  1653.6      0.18    9.2
# 202  216.385  1673.9      0.12    9.6
#
# [203 rows x 4 columns]

# %% [markdown]
# ### Calculate percentge change
#
# - An alternative to using percentge change is "log diferent"
# - In this method,the loganthm of one quantity is subtracted from the loganthm of another
# - The advantage of measuring change in this way is that the calculations are symmetrical going forward and backward

# %%
trans_data = np.log(data).diff().dropna()
trans_data
# Out:
#           cpi        m1  tbilrate     unemp
# 1    0.005849  0.014215  0.088193 -0.128617
# 2    0.006838 -0.008505  0.215321  0.038466
# 3    0.000681 -0.003565  0.125317  0.055060
# 4    0.005772 -0.002861 -0.212805 -0.074108
# 5    0.000338  0.004289 -0.266946  0.000000
# ..        ...       ...       ...       ...
# 198 -0.007904  0.045361 -0.396881  0.105361
# 199 -0.021979  0.066753 -2.277267  0.139762
# 200  0.002340  0.010286  0.606136  0.160343
# 201  0.008419  0.037461 -0.200671  0.127339
# 202  0.008894  0.012202 -0.405465  0.042560
#
# [202 rows x 4 columns]

# %% [markdown]
# ### Using scatter plot
#
# - Scatter plot is a useful way to examine the relatinship between two one-dimensional series
# - We use seaborn regplot method which make scatter plot and fits a linear regression line

# %%
# Figsize adjust as per requirment
fig,ax = plt.subplots(figsize = (8,6))
sns.regplot(x='m1',y='unemp',data=trans_data,ax=ax)
# Out:
# <AxesSubplot:xlabel='m1', ylabel='unemp'>

# %% [markdown]
# ## Pairplot or scatter plot matrix
#
# - In exploratory data analysis it is helpful to look at all scatter plots among a group of variables
# - This is known as pair plot or scatter plot matrix
# - We use seaborn's pairplot function which places histogram or density estimates of each variable along the diagonal

# %%
sns.pairplot(trans_data, diag_kind='kde', plot_kws={'alpha': 0.7})

# %%
sns.pairplot(trans_data, diag_kind='hist', plot_kws={'alpha': 0.7})

# %% [markdown]
# ### Facet Grid and Categorical Data
#
# - What if we have additional grouping dimensions
# - To visualize many categorical variables is to use facet grid
# - Seaborn's factorplot provides such functions to plot faceted plot

# %%
sns.catplot(x='day', y='tip_pct', hue='time', col='smoker', kind='bar', data=tips[tips['tip_pct'] < 1])

# %%
sns.catplot(x='day', y='tip_pct', row='time', col='smoker', kind='bar', data=tips[tips['tip_pct'] < 1])

# %% [markdown]
# ### Box plot
#
# - What if we want to visualize median, quantile, and outliers
# - Box plot can be effective way to visualize such type of data

# %%
sns.catplot(x='tip_pct', y='day', kind='box', data=tips[tips['tip_pct'] < 0.5])
